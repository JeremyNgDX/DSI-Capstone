# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.width', 100000)

# %%
dataset_names = ['S&P 500', 'Dow Jones', 'Nasdaq', 'Nikkei','STI','Hang Seng',\
                     'Bombay', 'ShangHai','FTSE100','Jakarta','Kuala Lumpur CI']

crash_names = [a + '_crash.csv' for a in dataset_names]

# %%
crash_names
# Out:
# ['S&P 500_crash.csv',
#  'Dow Jones_crash.csv',
#  'Nasdaq_crash.csv',
#  'Nikkei_crash.csv',
#  'STI_crash.csv',
#  'Hang Seng_crash.csv',
#  'Bombay_crash.csv',
#  'ShangHai_crash.csv',
#  'FTSE100_crash.csv',
#  'Jakarta_crash.csv',
#  'Kuala Lumpur CI_crash.csv']

# %%
df = pd.read_csv('S&P 500_crash.csv')
df1 = pd.read_csv('Dow Jones_crash.csv')
df2 = pd.read_csv('Nasdaq_crash.csv')
df3 = pd.read_csv('Nikkei_crash.csv')
df4 = pd.read_csv('STI_crash.csv')
df5 = pd.read_csv('Hang Seng_crash.csv')
df6 = pd.read_csv('Bombay_crash.csv')
df7 = pd.read_csv('ShangHai_crash.csv')
df8 = pd.read_csv('FTSE100_crash.csv')
df9 = pd.read_csv('Jakarta_crash.csv')
df10 = pd.read_csv('Kuala Lumpur CI_crash.csv')

# %%
dfs = [df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
for c,d in zip(crash_names,dfs):
    d = d.sort_values(ascending=False,by='rank')
    display(c,d)
# Out:
# 'S&P 500_crash.csv'
#           Date  drawdown             crash_st            crash_end  rank
# 0   1962/05/03 -0.058320  1962-05-03 00:00:00  1962-05-11 00:00:00    71
# 19  1980/03/19 -0.058384  1980-03-19 00:00:00  1980-03-27 00:00:00    70
# 64  2011/08/17 -0.058933  2011-08-17 00:00:00  2011-08-19 00:00:00    69
# 35  1998/09/29 -0.059703  1998-09-29 00:00:00  1998-10-01 00:00:00    68
# 21  1982/08/02 -0.060195  1982-08-02 00:00:00  1982-08-12 00:00:00    67
# 26  1987/11/05 -0.060830  1987-11-05 00:00:00  1987-11-10 00:00:00    66
# 6   1966/08/12 -0.060839  1966-08-12 00:00:00  1966-08-23 00:00:00    65
# 40  2001/02/15 -0.060869  2001-02-15 00:00:00  2001-02-23 00:00:00    64
# 23  1987/04/08 -0.060889  1987-04-08 00:00:00  1987-04-14 00:00:00    63
# 30  1990/07/31 -0.060986  1990-07-31 00:00:00  1990-08-06 00:00:00    62
# 68  2018/01/31 -0.061927  2018-01-31 00:00:00  2018-02-05 00:00:00    61
# 33  1998/07/30 -0.061971  1998-07-30 00:00:00  1998-08-04 00:00:00    60
# ...

# %%
df
# Out:
#           Date  drawdown             crash_st            crash_end  rank
# 0   1962/05/03 -0.058320  1962-05-03 00:00:00  1962-05-11 00:00:00    71
# 1   1962/05/15 -0.136724  1962-05-15 00:00:00  1962-05-28 00:00:00     4
# 2   1962/06/08 -0.070488  1962-06-08 00:00:00  1962-06-14 00:00:00    42
# 3   1962/06/15 -0.063875  1962-06-15 00:00:00  1962-06-26 00:00:00    57
# 4   1962/10/15 -0.066003  1962-10-15 00:00:00  1962-10-23 00:00:00    50
# 5   1966/04/21 -0.066003  1966-04-21 00:00:00  1966-05-09 00:00:00    51
# 6   1966/08/12 -0.060839  1966-08-12 00:00:00  1966-08-23 00:00:00    65
# 7   1969/07/17 -0.065581  1969-07-17 00:00:00  1969-07-29 00:00:00    52
# 8   1970/04/20 -0.064779  1970-04-20 00:00:00  1970-04-28 00:00:00    56
# 9   1970/05/18 -0.062370  1970-05-18 00:00:00  1970-05-21 00:00:00    59
# 10  1974/01/03 -0.074249  1974-01-03 00:00:00  1974-01-10 00:00:00    34
# 11  1974/07/24 -0.075303  1974-07-24 00:00:00  1974-08-02 00:00:00    32
# ...
